# %% [markdown]
# **Instalar LaTeX**

# %%
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# texlive-fonts-recommended is already the newest version (2021.20220204-1).
# texlive-plain-generic is already the newest version (2021.20220204-1).
# texlive-xetex is already the newest version (2021.20220204-1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %% [markdown]
# **Instalar pandoc**

# %%
# !sudo apt-get install pandoc -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pandoc is already the newest version (2.9.2.1-3ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %% [markdown]
# **Montar en el entorno desde el drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Generar el .PDF**

# %%
# !jupyter nbconvert --to PDF "/content/drive/My Drive/Colab Notebooks/AnalisisTitanic.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/My Drive/Colab Notebooks/AnalisisTitanic.ipynb to PDF
# [NbConvertApp] Support files will be in AnalisisTitanic_files/
# [NbConvertApp] Making directory ./AnalisisTitanic_files
# [NbConvertApp] Writing 64745 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 285724 bytes to /content/drive/My Drive/Colab Notebooks/AnalisisTitanic.pdf
